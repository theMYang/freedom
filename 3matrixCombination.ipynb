# %%
import numpy as np
import pandas as pd

from tqdm import tqdm_notebook

# %%
matrix_df = pd.read_csv('./data/trafficV201301_M.csv', index_col=0, parse_dates=True)
matrix_df.shape
# Out:
# (2976, 1024)

# %%
#np.array 24M
matrix_df
# Out:
#                      pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  \
# time
# 2013-01-01 00:00:00     7.0   13.75    11.5     9.0    7.00    14.5    16.0
# 2013-01-01 00:15:00     6.0   13.25    14.0     8.0    8.75    21.0    19.5
# 2013-01-01 00:30:00     5.0   16.00    19.0     7.0   13.25    29.5    26.5
# 2013-01-01 00:45:00     6.0   15.50    19.0     9.5   19.25    33.0    29.0
# 2013-01-01 01:00:00     5.0   14.50    21.5     9.0   15.00    30.5    42.0
# 2013-01-01 01:15:00     5.0   12.00    21.0     6.0   17.75    29.0    29.5
# 2013-01-01 01:30:00     6.0   11.00    17.5     6.0    9.25    20.0    22.0
# 2013-01-01 01:45:00     5.0   11.50    16.0     4.5   10.75    15.0    22.0
# 2013-01-01 02:00:00     3.0    9.13    11.0     6.0    9.75    16.5    17.5
# 2013-01-01 02:15:00     5.0    4.50    10.0     3.5    5.00    12.5    17.0
# 2013-01-01 02:30:00     3.0    5.00     8.0     5.5    5.50    11.0    12.0
# ...

# %%
# a = np.array(matrix_df[matrix_df.index == '2013-01-01 00:00:00']).reshape(-1, 32, 32)
# b = np.array(matrix_df[matrix_df.index == '2013-01-02 00:15:00']).reshape(-1, 32, 32)
# np.stack((a, b), axis=3).shape

# %%
week_delta = pd.Timedelta(1, unit='W')
matrix_df.index - week_delta
# Out:
# DatetimeIndex(['2012-12-25 00:00:00', '2012-12-25 00:15:00',
#                '2012-12-25 00:30:00', '2012-12-25 00:45:00',
#                '2012-12-25 01:00:00', '2012-12-25 01:15:00',
#                '2012-12-25 01:30:00', '2012-12-25 01:45:00',
#                '2012-12-25 02:00:00', '2012-12-25 02:15:00',
#                ...
#                '2013-01-24 21:30:00', '2013-01-24 21:45:00',
#                '2013-01-24 22:00:00', '2013-01-24 22:15:00',
#                '2013-01-24 22:30:00', '2013-01-24 22:45:00',
#                '2013-01-24 23:00:00', '2013-01-24 23:15:00',
#                '2013-01-24 23:30:00', '2013-01-24 23:45:00'],
#               dtype='datetime64[ns]', name='time', length=2976, freq='15T')

# %%
minute_delta = pd.Timedelta(15, unit='m')
matrix_df.index - minute_delta
# Out:
# DatetimeIndex(['2012-12-31 23:45:00', '2013-01-01 00:00:00',
#                '2013-01-01 00:15:00', '2013-01-01 00:30:00',
#                '2013-01-01 00:45:00', '2013-01-01 01:00:00',
#                '2013-01-01 01:15:00', '2013-01-01 01:30:00',
#                '2013-01-01 01:45:00', '2013-01-01 02:00:00',
#                ...
#                '2013-01-31 21:15:00', '2013-01-31 21:30:00',
#                '2013-01-31 21:45:00', '2013-01-31 22:00:00',
#                '2013-01-31 22:15:00', '2013-01-31 22:30:00',
#                '2013-01-31 22:45:00', '2013-01-31 23:00:00',
#                '2013-01-31 23:15:00', '2013-01-31 23:30:00'],
#               dtype='datetime64[ns]', name='time', length=2976, freq='15T')

# %% [markdown]
# Test for matrix combination

# %%
test_df = matrix_df[1000:2000]
test_before_week_df = matrix_df.loc[test_df.index - week_delta]

# %%
test_df
# Out:
#                      pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  \
# time
# 2013-01-11 10:00:00  156.25   181.0   155.5   141.0  142.00   242.5   218.5
# 2013-01-11 10:15:00  153.50   167.0   162.5   138.0  153.50   238.0   210.0
# 2013-01-11 10:30:00  145.00   182.5   157.0   150.0  156.50   240.0   209.5
# 2013-01-11 10:45:00  171.00   181.0   155.0   153.0  140.00   236.0   210.5
# 2013-01-11 11:00:00  156.50   178.0   161.0   178.5  148.50   239.0   202.0
# 2013-01-11 11:15:00  179.50   170.5   154.0   162.5  152.00   239.5   206.0
# 2013-01-11 11:30:00  175.50   175.5   167.0   188.0  157.50   253.0   223.5
# 2013-01-11 11:45:00  194.50   181.5   172.5   196.5  153.25   226.5   245.5
# 2013-01-11 12:00:00  188.50   178.0   172.5   218.5  159.50   237.5   240.0
# 2013-01-11 12:15:00  198.50   185.5   186.5   240.5  164.50   248.0   262.0
# 2013-01-11 12:30:00  212.00   204.5   197.5   260.0  175.25   268.5   274.5
# ...

# %%
test_before_week_df
# Out:
#                      pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  \
# time
# 2013-01-11 09:45:00  167.00   188.5   161.5   138.0  149.75   271.0   207.5
# 2013-01-11 10:00:00  156.25   181.0   155.5   141.0  142.00   242.5   218.5
# 2013-01-11 10:15:00  153.50   167.0   162.5   138.0  153.50   238.0   210.0
# 2013-01-11 10:30:00  145.00   182.5   157.0   150.0  156.50   240.0   209.5
# 2013-01-11 10:45:00  171.00   181.0   155.0   153.0  140.00   236.0   210.5
# 2013-01-11 11:00:00  156.50   178.0   161.0   178.5  148.50   239.0   202.0
# 2013-01-11 11:15:00  179.50   170.5   154.0   162.5  152.00   239.5   206.0
# 2013-01-11 11:30:00  175.50   175.5   167.0   188.0  157.50   253.0   223.5
# 2013-01-11 11:45:00  194.50   181.5   172.5   196.5  153.25   226.5   245.5
# 2013-01-11 12:00:00  188.50   178.0   172.5   218.5  159.50   237.5   240.0
# 2013-01-11 12:15:00  198.50   185.5   186.5   240.5  164.50   248.0   262.0
# ...

# %%
# qwe = np.array(test_df.iloc[0:2]).reshape(-1,32,32)
# asd = np.array(test_before_week_df.iloc[0:2]).reshape(-1,32,32)
# np.stack((qwe, asd), axis=2)

# %%
qwe = np.array(test_df.iloc[0:10]).reshape(-1,32,32,1)
asd = np.array(test_before_week_df.iloc[0:10]).reshape(-1,32,32,1)
np.concatenate((qwe, asd), axis=3).shape
# Out:
# (10, 32, 32, 2)

# %%
qwe.shape, asd.shape
# Out:
# ((10, 32, 32, 1), (10, 32, 32, 1))

# %% [markdown]
# 画图

# %%
matrix_df.shape

# %%
import random
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (9.0, 9.0) # 设置figure_size尺寸

# %%
48*15/60

# %%
num = random.randint(0, 2976)
pic_matrix = matrix_df.iloc[num].reshape(32, 32)
# pic_matrix = (pic_matrix - pic_matrix.min())/(pic_matrix.max() - pic_matrix.min())*255
print((num%96)*15/60)
plt.imshow(pic_matrix)
