# %%
import numpy as np
import pandas as pd

from tqdm import tqdm_notebook

# %%
matrix_df = pd.read_csv('./data/trafficV201306_M.csv', index_col=0, parse_dates=True)
matrix_df.shape
# Out:
# (2880, 1024)

# %%
#np.array 24M
matrix_df
# Out:
#                      pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  \
# time
# 2013-06-01 00:00:00    20.5   26.50    38.5    41.5   30.00    49.0    58.5
# 2013-06-01 00:15:00    21.0   26.00    35.0    33.0   24.75    44.5    52.0
# 2013-06-01 00:30:00    17.5   27.38    29.0    26.0   22.25    38.5    45.5
# 2013-06-01 00:45:00    17.0   23.00    27.5    23.5   22.00    36.5    39.0
# 2013-06-01 01:00:00    17.0   20.00    24.0    18.0   16.50    33.0    35.0
# 2013-06-01 01:15:00    16.5   21.00    19.5    20.5   17.38    35.5    32.5
# 2013-06-01 01:30:00    12.0   17.50    17.5    16.5   13.75    32.0    26.5
# 2013-06-01 01:45:00    12.5   13.50    15.5    19.5   13.75    33.0    25.5
# 2013-06-01 02:00:00    11.0   15.75    19.5    18.5   11.75    36.5    21.5
# 2013-06-01 02:15:00    10.5   15.75    14.0    15.0   10.25    37.5    23.0
# 2013-06-01 02:30:00    12.0   15.94    12.5    10.5   12.63    35.0    18.0
# ...

# %%
# a = np.array(matrix_df[matrix_df.index == '2013-01-01 00:00:00']).reshape(-1, 32, 32)
# b = np.array(matrix_df[matrix_df.index == '2013-01-02 00:15:00']).reshape(-1, 32, 32)
# np.stack((a, b), axis=3).shape

# %%
week_delta = pd.Timedelta(1, unit='W')
matrix_df.index - week_delta
# Out:
# DatetimeIndex(['2013-05-25 00:00:00', '2013-05-25 00:15:00',
#                '2013-05-25 00:30:00', '2013-05-25 00:45:00',
#                '2013-05-25 01:00:00', '2013-05-25 01:15:00',
#                '2013-05-25 01:30:00', '2013-05-25 01:45:00',
#                '2013-05-25 02:00:00', '2013-05-25 02:15:00',
#                ...
#                '2013-06-23 21:30:00', '2013-06-23 21:45:00',
#                '2013-06-23 22:00:00', '2013-06-23 22:15:00',
#                '2013-06-23 22:30:00', '2013-06-23 22:45:00',
#                '2013-06-23 23:00:00', '2013-06-23 23:15:00',
#                '2013-06-23 23:30:00', '2013-06-23 23:45:00'],
#               dtype='datetime64[ns]', name='time', length=2880, freq='15T')

# %%
minute_delta = pd.Timedelta(15, unit='m')
matrix_df.index - minute_delta
# Out:
# DatetimeIndex(['2013-05-31 23:45:00', '2013-06-01 00:00:00',
#                '2013-06-01 00:15:00', '2013-06-01 00:30:00',
#                '2013-06-01 00:45:00', '2013-06-01 01:00:00',
#                '2013-06-01 01:15:00', '2013-06-01 01:30:00',
#                '2013-06-01 01:45:00', '2013-06-01 02:00:00',
#                ...
#                '2013-06-30 21:15:00', '2013-06-30 21:30:00',
#                '2013-06-30 21:45:00', '2013-06-30 22:00:00',
#                '2013-06-30 22:15:00', '2013-06-30 22:30:00',
#                '2013-06-30 22:45:00', '2013-06-30 23:00:00',
#                '2013-06-30 23:15:00', '2013-06-30 23:30:00'],
#               dtype='datetime64[ns]', name='time', length=2880, freq='15T')

# %% [markdown]
# Test for matrix combination

# %%
test_df = matrix_df[1000:2000]
test_before_week_df = matrix_df.loc[test_df.index - week_delta]

# %%
test_df
# Out:
#                      pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  \
# time
# 2013-06-11 10:00:00   251.5   200.0  184.50   170.0  136.63  267.00  219.00
# 2013-06-11 10:15:00   233.0   193.5  187.50   160.5  137.38  263.50  217.50
# 2013-06-11 10:30:00   229.5   177.0  170.50   162.5  142.13  249.00  204.50
# 2013-06-11 10:45:00   200.0   174.0  171.50   161.0  131.88  251.00  213.50
# 2013-06-11 11:00:00   206.0   178.5  168.00   158.5  133.75  240.50  204.50
# 2013-06-11 11:15:00   197.0   176.0  174.00   165.0  139.13  246.50  220.50
# 2013-06-11 11:30:00   212.5   172.5  156.00   178.5  137.38  246.50  219.00
# 2013-06-11 11:45:00   194.0   164.0  158.00   173.0  137.13  246.00  230.00
# 2013-06-11 12:00:00   181.5   171.0  167.00   160.5  144.38  244.50  233.00
# 2013-06-11 12:15:00   181.0   181.0  171.00   175.0  139.38  254.50  233.50
# 2013-06-11 12:30:00   170.0   190.5  176.00   171.5  145.75  266.50  245.00
# ...

# %%
test_before_week_df
# Out:
#                      pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  \
# time
# 2013-06-04 10:00:00   264.0   205.5   184.5   173.5  137.88   253.5   220.5
# 2013-06-04 10:15:00   250.0   193.5   189.0   163.0  137.38   273.0   211.0
# 2013-06-04 10:30:00   238.5   177.0   173.0   171.0  143.38   260.0   209.0
# 2013-06-04 10:45:00   200.0   178.5   171.5   164.0  133.63   251.0   208.0
# 2013-06-04 11:00:00   208.5   178.5   168.0   161.5  137.25   240.5   208.0
# 2013-06-04 11:15:00   197.0   176.0   168.0   166.0  140.38   246.5   223.0
# 2013-06-04 11:30:00   212.5   174.0   162.5   178.5  138.13   243.0   228.0
# 2013-06-04 11:45:00   194.0   163.5   162.5   173.5  137.38   246.5   230.0
# 2013-06-04 12:00:00   181.5   179.0   167.0   172.0  145.13   244.5   233.5
# 2013-06-04 12:15:00   181.0   181.0   171.0   180.0  139.13   254.5   246.5
# 2013-06-04 12:30:00   170.0   188.5   175.5   173.5  147.25   266.5   245.0
# ...

# %%
# qwe = np.array(test_df.iloc[0:2]).reshape(-1,32,32)
# asd = np.array(test_before_week_df.iloc[0:2]).reshape(-1,32,32)
# np.stack((qwe, asd), axis=2)

# %%
qwe = np.array(test_df.iloc[0:10]).reshape(-1,32,32,1)
asd = np.array(test_before_week_df.iloc[0:10]).reshape(-1,32,32,1)
np.concatenate((qwe, asd), axis=3).shape
# Out:
# (10, 32, 32, 2)

# %%
qwe.shape, asd.shape
# Out:
# ((10, 32, 32, 1), (10, 32, 32, 1))

# %% [markdown]
# 画图

# %%
matrix_df.shape
# Out:
# (2880, 1024)

# %%
import random
import matplotlib.pyplot as plt
import matplotlib as mpl

Chinesefont = mpl.font_manager.FontProperties(fname='C:\Windows\Fonts\simsun.ttc')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12.0, 12.0) # 设置figure_size尺寸

# %%
a = np.array(matrix_df[matrix_df.index == '2013-01-01 00:00:00']).reshape(-1, 32, 32)

# %%
num = 45 # random.randint(0, 2976)
# pic_matrix = matrix_df.iloc[num].reshape(32, 32)
pic_matrix = np.array(matrix_df[matrix_df.index == '2013-06-5 21:00:00']).reshape(32, 32)
# pic_matrix = (pic_matrix - pic_matrix.min())/(pic_matrix.max() - pic_matrix.min())*255
print((num%96)*15/60)
plt.xticks([])
plt.yticks([])

gci = plt.imshow(pic_matrix, cmap='rainbow')
cbar = plt.colorbar(gci, fraction=0.0455)
cbar.set_label('交通量(辆/小时)', FontProperties=Chinesefont, size=14)  

plt.savefig("volume0605_21.png", dpi=300)
# Out:
# 11.25

# %%
num = 45 # random.randint(0, 2976)
# pic_matrix = matrix_df.iloc[num].reshape(32, 32)
pic_matrix = np.array(matrix_df[matrix_df.index == '2013-06-05 21:00:00']).reshape(32, 32)
# pic_matrix = (pic_matrix - pic_matrix.min())/(pic_matrix.max() - pic_matrix.min())*255
print((num%96)*15/60)
plt.xticks([])
plt.yticks([])

gci = plt.imshow(pic_matrix, cmap='rainbow')
cbar = plt.colorbar(gci, fraction=0.0455)
cbar.set_label('交通量(辆/小时)', FontProperties=Chinesefont, size=14)
# Out:
# 11.25

# %%
# num = 45 # random.randint(0, 2976)
# # pic_matrix = matrix_df.iloc[num].reshape(32, 32)
# pic_matrix = np.array(matrix_df[matrix_df.index == '2013-06-08 8:00:00']).reshape(32, 32)

# f,((ax11,ax12,ax13),(ax21,ax22,ax23),(ax31,ax32,ax33)) = plt.subplots(3,3,sharex=True,sharey=True)

# gci = ax11.imshow(pic_matrix, cmap='rainbow')
# cbar = plt.colorbar(gci, fraction=0.0455)
# cbar.set_label('交通量(辆/小时)', FontProperties=Chinesefont, size=14)
